# %%
import argparse
import sys
import warnings
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


warnings.filterwarnings("ignore")

# %%
# Import dataset

data = pd.read_feather(
    "/mnt/upramdya_data/MD/F1_Tracks/Datasets/260123_14_F1_coordinates_F1_TNT_Full_Data/summary/pooled_summary.feather"
)

# %%
data.head()
# Out:
#    time_to_first_interaction  ball_proximity_proportion_70px  max_event  \
# 0                 454.586207                        0.310181        0.0
# 1                  34.482759                        0.066816        1.0
# 2                 753.448276                             NaN        1.0
# 3                        NaN                        0.058843        NaN
# 4                 449.448276                             NaN       15.0
#
#   raw_pauses  interaction_rate_bin_7  interaction_rate_bin_11  \
# 0         []                0.003535                 0.010605
# 1         []                0.000000                 0.000000
# 2         []                0.000000                 0.000000
# 3         []                0.000000                 0.000000
# 4         []                0.000000                 0.000000
#
#    persistence_at_end  binned_slope_10  velocity_during_interactions  \
# 0            0.772151         0.003429                      3.007835
# ...

# %%
# Print column names one per line
for col in data.columns:
    print(col)
# Out:
# time_to_first_interaction
# ball_proximity_proportion_70px
# max_event
# raw_pauses
# interaction_rate_bin_7
# interaction_rate_bin_11
# persistence_at_end
# binned_slope_10
# velocity_during_interactions
# binned_slope_8
# binned_auc_4
# total_stop_duration
# binned_auc_8
# major_event_first
# binned_auc_3
# interaction_rate_bin_4
# binned_slope_3
# velocity_trend
# overall_slope
# cumulated_breaks_duration
# chamber_ratio
# final_event
# interaction_rate_bin_10
# final_event_time
# binned_slope_0
# distance_ratio
# interaction_rate_bin_3
# binned_auc_2
# pulled
# binned_slope_5
# interaction_rate_bin_8
# interaction_rate_bin_0
# ball_identity
# auc
# ball_proximity_proportion_200px
# max_distance
# median_stop_duration
# interaction_proportion
# nb_significant_events
# f1_exit_time
# logistic_L
# interaction_rate_bin_1
# binned_slope_7
# logistic_k
# chamber_time
# fly_idx
# nb_pauses
# chamber_exit_time
# interaction_rate_bin_5
# significant_ratio
# learning_slope_r2
# ...

# %%
# get a value of fly randomly
random_fly = data.sample(n=1, random_state=42)
print(random_fly["fly"])
# Out:
# 16    260114_TNT_F1_Videos_Checked_arena1_Left
# Name: fly, dtype: object
