# %%
from pathlib import Path
import sys

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import importlib

src_path = Path.cwd().parent / "src"
if src_path not in sys.path:
    sys.path.append(str(src_path))

from Ballpushing_utils import Experiment, Fly, Dataset

from utils_behavior import Processing
# Out:
# <frozen importlib._bootstrap>:488: RuntimeWarning: Your system is avx2 capable but pygame was not built with support for it. The performance of some of your blits could be adversely affected. Consider enabling compile time detection with environment variables like PYGAME_DETECT_AVX2=1 if you are compiling without cross compilation.
# pygame 2.6.0 (SDL 2.30.7, Python 3.12.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
output_dir = Path("/mnt/upramdya_files/DURRIEU_Matthias/Pictures/250411_TeamMeeting")

# %% [markdown]
# # Generate a Fly object

# %%
ExampleFly_path = Path(
    "/mnt/upramdya_data/MD/MultiMazeRecorder/Videos/231130_TNT_Fine_2_Videos_Tracked/arena2/corridor5"
)

ExampleFly = Fly(ExampleFly_path, as_individual=True)
# Out:
#  Time range: None

# %%
event_dataset = Dataset(ExampleFly, dataset_type="event_metrics")
# Out:
# Fly 0 chamber exit time: 14.758620689655173
# Ball data time range: 0.034482758620689655 to 3600.0689655172414
# Threshold for fly 0, ball 0: 170
# Final event for fly 0, ball 0: [np.int64(79792), np.int64(80332), np.int64(540)]

# %%
event_dataset.data
# Out:
#    index   start_time     end_time   duration  displacement  start_distance  \
# 0      0    14.758621    30.586207  15.827586     73.027395        1.655937
# 1      1  2108.034483  2110.896552   2.862069      1.059913       79.533432
# 2      2  2192.586207  2210.000000  17.413793     53.784265       59.513834
# 3      3  2218.655172  2221.241379   2.586207      1.886804      124.159408
# 4      4  2751.448276  2770.068966  18.620690     90.625533      111.709607
# 5      5  2826.689655  2828.758621   2.068966      0.077724      202.019842
# 6      6  3127.551724  3166.068966  38.517241     77.645402      124.698150
# 7      7  3577.206897  3588.068966  10.862069      5.939302      177.559403
#
#    end_distance  direction  significant  major_event  ...  Brain region  \
# 0     71.703448          1            1            1  ...            LH
# 1     78.963602          0            0            0  ...            LH
# 2    113.253384          1            1            1  ...            LH
# 3    125.351622          0            0            0  ...            LH
# 4    202.312544          1            1            1  ...            LH
# 5    202.033550          0            0            0  ...            LH
# 6    202.343048          1            1            1  ...            LH
# 7    183.498576          1            1            0  ...            LH
#
#    Simplified Nickname  Split    Date   Genotype Period     FeedingState  \
# 0                 LH18      y  231130  TNTxZ1898   PM15  starved_noWater
# 1                 LH18      y  231130  TNTxZ1898   PM15  starved_noWater
# 2                 LH18      y  231130  TNTxZ1898   PM15  starved_noWater
# 3                 LH18      y  231130  TNTxZ1898   PM15  starved_noWater
# 4                 LH18      y  231130  TNTxZ1898   PM15  starved_noWater
# 5                 LH18      y  231130  TNTxZ1898   PM15  starved_noWater
# 6                 LH18      y  231130  TNTxZ1898   PM15  starved_noWater
# 7                 LH18      y  231130  TNTxZ1898   PM15  starved_noWater
#
#    Orientation  Light Crossing
# 0          std     on        1
# 1          std     on        1
# 2          std     on        1
# 3          std     on        1
# 4          std     on        1
# 5          std     on        1
# 6          std     on        1
# 7          std     on        1
#
# [8 rows x 33 columns]
