# %%
import pandas as pd

# %%
# Load data

pca_df = pd.read_feather("/home/durrieu/ballpushing_utils/src/Plotting/pca_with_metadata.feather")

# %%
pca_df.head()
# Out:
#         PC1       PC2       PC3         index success_direction  \
# 0  1.241248 -0.703853 -0.507349  fly_0_ball_0              push
# 1  0.283817  2.503886 -1.476730  fly_0_ball_0              push
# 2  1.146261  0.230708 -0.700511  fly_0_ball_0              push
# 3  0.806489 -1.725778  1.819976  fly_0_ball_0              push
# 4 -0.958551 -2.749121 -0.293052  fly_0_ball_0              both
#
#    learning_slope  learning_slope_r2    logistic_L  logistic_k   logistic_t0  \
# 0       -0.033645           0.522880  1.344462e+07   -0.000282 -39028.324796
# 1       -0.028951           0.324865  8.837810e+06   -0.000266 -40005.817998
# 2       -0.028377           0.488745  5.158701e+06   -0.000219 -46115.910145
# 3       -0.013058           0.195850  1.427195e+06   -0.000116 -78431.527864
# 4       -0.084497           0.683144  9.612304e+02   -0.000607   -609.746944
#
#    ...  Brain region Simplified Nickname Split    Date   Genotype Period  \
# ...
