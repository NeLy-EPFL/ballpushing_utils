# %%
import pandas as pd
import seaborn as sns

# %%
# Load dataset:

UMAP = pd.read_feather("/mnt/upramdya_data/MD/Ballpushing_Exploration/Datasets/250410_BallpushingMetrics_Data/transposed/pooled_transposed_umap.feather")

# %%
UMAP.head()
# Out:
#       UMAP1      UMAP2  index  \
# 0  9.329734  -4.458492      0
# 1  1.801910  10.347840      1
# 2  9.272248  -4.506442      2
# 3  9.587728  13.228127      3
# 4  9.445966  13.311653      4
#
#                                                  fly  event_id   event_type  \
# 0  230706_FeedingState_3_PM_Flipped_Videos_Tracke...         0  interaction
# 1  230706_FeedingState_3_PM_Flipped_Videos_Tracke...         1  interaction
# 2  230706_FeedingState_3_PM_Flipped_Videos_Tracke...         2  interaction
# 3  230706_FeedingState_3_PM_Flipped_Videos_Tracke...         3  interaction
# 4  230706_FeedingState_3_PM_Flipped_Videos_Tracke...         4  interaction
#
#    centre_preprocessed_fly_frame0_x  centre_preprocessed_fly_frame1_x  \
# 0                        -10.821976                        -10.804033
# 1                         -8.043168                         -8.483940
# 2                          3.129240                          3.111315
# ...

# %%
# Plot umap

sns.set(style="whitegrid")

sns.scatterplot(x="UMAP1", y="UMAP2", hue="cluster", data=UMAP, alpha=0.5, s=10)
# Out:
# <Axes: xlabel='UMAP1', ylabel='UMAP2'>
